# %%
import pandas as pd

# %% [markdown]
# ## Read in data

# %% [markdown]
# First need to read in and split by new line, then split by tab delimiter and expand the columns out.

# %%
df = pd.read_csv('output.txt', header=None, sep='\n', encoding = 'utf-8')

# %%
df = df[0].str.split('\t', expand=True)

# %% [markdown]
# Rename columns

# %%
column_names = [
    "Tissue",
    "Adult Male FPKM",
    "Adult Male SD",
    "Adult Male Enrichment",
    "Adult Female FPKM",
    "Adult Female SD",
    "Adult Female Enrichment",
    "Male v. Female M/F",
    "Male v. Female p value",
    "Larval FPKM",
    "Larval SD",
    "Larval Enrichment",
]
df.columns = column_names

# %% [markdown]
# Extract FlyBase ID, Annotation Symbol, Symbol and Name

# %%
df.loc[df.Tissue == "FlyBase ID", "FlyBase ID"] = df["Adult Male FPKM"]
df.loc[df.Tissue == "Annotation Symbol", "Annotation Symbol"] = df["Adult Male FPKM"]
df.loc[df.Tissue == "Symbol", "Symbol"] = df["Adult Male FPKM"]
df.loc[df.Tissue == "Name", "Name"] = df["Adult Male FPKM"]
# Out:
#               Tissue Adult Male FPKM Adult Male SD Adult Male Enrichment  \
# 0         FlyBase ID     FBgn0053503          None                  None
# 1  Annotation Symbol         CG33503          None                  None
# 2             Symbol       Cyp12d1-d          None                  None
# 3               Name       Cyp12d1-d          None                  None
# 4                         Adult Male
#
#   Adult Female FPKM Adult Female SD Adult Female Enrichment  \
# 0              None            None                    None
# 1              None            None                    None
# 2              None            None                    None
# 3              None            None                    None
# 4      Adult Female
#
#   Male v. Female M/F Male v. Female p value Larval FPKM Larval SD  \
# 0               None                   None        None      None
# 1               None                   None        None      None
# 2               None                   None        None      None
# 3               None                   None        None      None
# 4     Male v. Female                             Larval      None
#
#   Larval Enrichment   FlyBase ID Annotation Symbol     Symbol       Name
# 0              None  FBgn0053503               NaN        NaN        NaN
# 1              None          NaN           CG33503        NaN        NaN
# 2              None          NaN               NaN  Cyp12d1-d        NaN
# 3              None          NaN               NaN        NaN  Cyp12d1-d
# 4              None          NaN               NaN        NaN        NaN

# %% [markdown]
# Fill forward the new columns

# %%
columns_to_fill_forward = ['FlyBase ID', 'Annotation Symbol', 'Symbol', 'Name']
for name in columns_to_fill_forward:
    df[name] = df[name].fillna(method='ffill')

# %% [markdown]
# ### Remove errors and pointless rows

# %%
remove_rows_containing = ["An error has occurred.",
                          "FlyBase ID",
                          "Annotation Symbol",
                          "Symbol", 
                          "Name", 
                          "Tissue",
                         ""]
df = df[~df.Tissue.isin(remove_rows_containing)]
df.head()
# Out:
#                          Tissue Adult Male FPKM Adult Male SD  \
# 6                    Whole body             0.0             0
# 7                          Head             0.0             0
# 8                           Eye             0.0             0
# 9                   Brain / CNS             0.0             0
# 10  Thoracicoabdominal ganglion             0.0             0
#
#    Adult Male Enrichment Adult Female FPKM Adult Female SD  \
# 6                     -1               0.0               0
# 7                     -1               0.0               0
# 8                     -1               0.0               0
# 9                     -1               0.0               0
# 10                    -1               0.0            0.01
#
#    Adult Female Enrichment Male v. Female M/F Male v. Female p value  \
# 6                       -1               1.00                   n.s.
# 7                       -1               1.00                   n.s.
# 8                       -1               1.00                   n.s.
# 9                       -1               1.00                   n.s.
# 10                      -1               1.00                   n.s.
#
#    Larval FPKM Larval SD Larval Enrichment   FlyBase ID Annotation Symbol  \
# 6          0.0         0                -1  FBgn0053503           CG33503
# 7            -         -                 -  FBgn0053503           CG33503
# 8            -         -                 -  FBgn0053503           CG33503
# 9          0.0         0                -1  FBgn0053503           CG33503
# 10           -         -                 -  FBgn0053503           CG33503
#
#        Symbol       Name
# 6   Cyp12d1-d  Cyp12d1-d
# 7   Cyp12d1-d  Cyp12d1-d
# 8   Cyp12d1-d  Cyp12d1-d
# 9   Cyp12d1-d  Cyp12d1-d
# 10  Cyp12d1-d  Cyp12d1-d
